# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/REDD-NILM/blob/master/24-May-2026-Advanced-LNN-v5-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/REDD-NILM
# Out:
# /content/REDD-NILM

# %%
# %pwd
# Out:
# '/content/REDD-NILM'

# %%
# !python test_advanced_lnn_v5_redd.py
# Out:
# Loading REDD splits...
#   train_small    :  28,800 rows
#   val_small      :  28,800 rows
#   test_small     :  28,800 rows  (House 3, 2011-04-30)
#
# ...
# Advanced LNN v5 REDD — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda  tau_fast=(0.01, 1.0)  tau_slow=(0.5, 8.0)
#   Parameters: 10,946
#     Ep   1  train=0.03495  val=0.02216  F1=0.0754  P=0.0392  R=1.0000  MAE=57.89  SAE=56.5381  TP=225  FP=5515  TN=0  FN=0  time=58.9s
# Model successfully saved to: models/advanced_lnn_v5_redd_20260524_034236/dishwasher/dishwasher_best.pth
#     Ep   2  train=0.02314  val=0.01829  F1=0.2080  P=0.1161  R=1.0000  MAE=37.80  SAE=34.6330  TP=225  FP=1713  TN=3802  FN=0  time=57.0s
# Model successfully saved to: models/advanced_lnn_v5_redd_20260524_034236/dishwasher/dishwasher_best.pth
#     Ep   3  train=0.02196  val=0.01725  F1=0.1959  P=0.1086  R=1.0000  MAE=33.28  SAE=29.7916  TP=225  FP=1847  TN=3668  FN=0  time=56.9s
# ...
