# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/REDD-NILM/blob/master/19-July-2026-APR-REDD-Base-models-combined-LNN-test-run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/REDD-NILM
# Out:
# /content/REDD-NILM

# %%
# %pwd
# Out:
# '/content/REDD-NILM'

# %%
# !python APR-scripts-REDD/test_gru_redd_dataset.py
# Out:
# Testing GRU on REDD dataset...
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (57580, 100, 1) -> (57580, 1)
# Validation sequences: (17260, 100, 1) -> (17260, 1)
# Test sequences:       (23000, 100, 1) -> (23000, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 1800/1800 [00:03<00:00, 524.79it/s, loss=0.000964]
# Epoch 1/80, Train Loss: 0.009751, Val Loss: 0.010736, Val MAE: 52.41, Val SAE: 43.40, Val F1: 0.1159, Val Precision: 0.0618, Val Recall: 0.9273
# ...

# %%
# !python APR-scripts-REDD/test_lstm_redd_dataset.py
# Out:
# Testing LSTM on REDD dataset...
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (57580, 100, 1) -> (57580, 1)
# Validation sequences: (17260, 100, 1) -> (17260, 1)
# Test sequences:       (23000, 100, 1) -> (23000, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 1800/1800 [00:05<00:00, 343.71it/s, loss=0.0537]
# Epoch 1/80, Train Loss: 0.010372, Val Loss: 0.011059, Val MAE: 57.38, Val SAE: 53.28, Val F1: 0.0589, Val Precision: 0.0304, Val Recall: 1.0000
# ...

# %%
# !python APR-scripts-REDD/test_resnet_redd_dataset.py
# Out:
# Testing ResNet on REDD dataset...
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Testing ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (57580, 100, 1) -> (57580, 1)
# Validation sequences: (17260, 100, 1) -> (17260, 1)
# Test sequences:       (23000, 100, 1) -> (23000, 1)
# Starting ResNet training for dishwasher...
# Epoch 1/80: 100% 1800/1800 [00:06<00:00, 290.83it/s, loss=0.00233]
# Epoch 1/80, Train Loss: 0.012828, Val Loss: 0.009874, Val MAE: 52.39, Val SAE: 38.84, Val F1: 0.2732, Val Precision: 0.1674, Val Recall: 0.7426
# ...

# %%
# !python APR-scripts-REDD/test_tcn_redd_dataset.py
# Out:
# Testing TCN on REDD dataset...
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Testing TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (57580, 100, 1) -> (57580, 1)
# Validation sequences: (17260, 100, 1) -> (17260, 1)
# Test sequences:       (23000, 100, 1) -> (23000, 1)
# Starting TCN training for dishwasher...
# Epoch 1/80: 100% 1800/1800 [00:02<00:00, 862.08it/s, loss=1.59e-5]
# Epoch 1/80, Train Loss: 0.005711, Val Loss: 0.006072, Val MAE: 22.57, Val SAE: 16.88, Val F1: 0.2948, Val Precision: 0.2044, Val Recall: 0.5285
# ...

# %%
# !python APR-scripts-REDD/test_transformer_redd_dataset.py
# Out:
# Testing Transformer on REDD dataset...
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Testing Transformer on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (57580, 100, 1) -> (57580, 1)
# Validation sequences: (17260, 100, 1) -> (17260, 1)
# Test sequences:       (23000, 100, 1) -> (23000, 1)
# Starting Transformer training for dishwasher...
# Epoch 1/80: 100% 1800/1800 [00:06<00:00, 276.86it/s, loss=0.000782]
# Epoch 1/80, Train Loss: 0.038799, Val Loss: 0.012016, Val MAE: 41.85, Val SAE: 35.10, Val F1: 0.1686, Val Precision: 0.0922, Val Recall: 0.9804
# ...

# %%
# !python APR-scripts-REDD/test_rf_redd_dataset.py
# Out:
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Training RandomForestRegressor on dishwasher
# ...
#
# Building windowed features for dishwasher...
#   Train: (57580, 10)  ON=2.88%
#   Val:   (17260, 10)  ON=2.95%
#   Test:  (23000, 10)  ON=1.58%
# Fitting RandomForestRegressor (300 trees) for dishwasher...
#   Val  -- F1=0.5091  P=0.3541  R=0.9057  MAE=15.90  SAE=7.7351
#   Test -- F1=0.3428  P=0.2102  R=0.9284  MAE=9.06  SAE=5.8348  TP=337  TN=21,371  FP=1,266  FN=26
#
# ...
# Training RandomForestRegressor on fridge
# ...
#
# Building windowed features for fridge...
#   Train: (57580, 10)  ON=19.05%
# ...

# %%
# !python APR-scripts-REDD/test_lnn_redd_dataset.py
# Out:
# Testing LNN on REDD dataset...
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
#
# ...
# Testing LNN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (57580, 100, 1) -> (57580, 1)
# Validation sequences: (17260, 100, 1) -> (17260, 1)
# Test sequences:       (23000, 100, 1) -> (23000, 1)
# Starting LNN training for dishwasher...
# Epoch 1/80: 100% 1800/1800 [00:35<00:00, 51.22it/s, loss=0.000165]
# Epoch 1/80, Train Loss: 0.009783, Val Loss: 0.014543, Val MAE: 59.45, Val SAE: 54.34, Val F1: 0.1107, Val Precision: 0.0586, Val Recall: 1.0000
# ...

# %%
# !python APR-scripts-REDD/test_pinn_lnn_redd_dataset.py
# Out:
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows  2011-04-18 00:00:00-04:00 -> 2011-04-27 23:59:57-04:00
#   val   :  86,400 rows  2011-04-30 00:00:00-04:00 -> 2011-05-02 23:59:57-04:00
#   test[0]:  57,600 rows  2011-05-11 00:00:00-04:00 -> 2011-05-12 23:59:57-04:00
#   test[1]:  57,600 rows  2011-05-23 00:00:00-04:00 -> 2011-05-24 23:59:57-04:00
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train ON-rate:  {'dishwasher': 2.88, 'fridge': 19.05, 'microwave': 1.45, 'washing_machine': 0.71}
# MSE weights:    {'dishwasher': 1.0, 'fridge': 0.323, 'microwave': 1.169, 'washing_machine': 1.678}
# Train: (57580, 100, 1) -> (57580, 4)
# Val:   (17260, 100, 1) -> (17260, 4)
# Test:  (23000, 100, 1) -> (23000, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
# ...

# %%
# !python APR-scripts-REDD/combined_pinn_lnn_redd_dataset.py
# Out:
# Loading REDD CSV data from '/content/REDD-NILM/APR-scripts-REDD/../APR-new-REDD-dataset' ...
#   train : 288,000 rows
#   val   :  86,400 rows
#   test[0]:  57,600 rows
#   test[1]:  57,600 rows
#   Columns: ['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               26.0     26.0     26.0
#   microwave            24.0     24.0     24.0
#   washing_machine      21.0     21.0     21.0
#
# Creating sequences ...
#   Train : (28771, 299, 8) -> (28771, 299, 4)  (8,602,529 predictions)
#   Val   : (8611, 299, 8) -> (8611, 299, 4)
#   Test  : (384, 299, 8) -> (384, 299, 4)  [non-overlapping, 2 blocks]
#
#   Agg Z-score: mean=330.5 W  std=628.7 W
#
#   Gate pos_weight per appliance:
# ...
